# %%
from cassis import *
from pathlib import Path
import os
import pandas as pd
import numpy as np
import krippendorff
import zipfile
from itertools import chain
from sklearn.metrics import cohen_kappa_score

# %%
def get_nested_key_by_annotator(annotator, key, dictionary):
    return dictionary[annotator][key]

def get_text_span_indices(span):
    return [span.begin, span.end]

def get_text_span_event_type_andre(span):
    return span.Events

def get_text_span_event_type_nuclei(span):
    return span.nuclei

def get_text_span_event_direction(span):
    return span.DirectionofChange

def spans_overlap(span_1, span_2):
    return set(list(range(*get_text_span_indices(span_1)))).intersection(list(range(*get_text_span_indices(span_2))))

# %% [markdown]
# Pilot 1

# %%
from collections import Counter
counter = Counter(all_docs)
print(counter)
def count_by_frequency(counter_obj):
    """
    Given a Counter, return the number of items
    that occur exactly 3 times, 2 times, and 1 time.
    """
    counts = counter_obj.values()
    return {
        3: sum(1 for c in counts if c == 3),
        2: sum(1 for c in counts if c == 2),
        1: sum(1 for c in counts if c == 1),
        0: sum(1 for c in counts if c == 0)
    }
count_frequency = count_by_frequency(counter)
# Out:
# Counter({'29.txt': 3, '28.txt': 3, '17.txt': 3, '12.txt': 3, '11.txt': 3, 'narrative_20.txt': 3, 'narrative_19.txt': 3, 'narrative_18.txt': 3, 'narrative_16.txt': 3, '4.txt': 3, 'narrative_17.txt': 3, 'narrative_15.txt': 3, 'narrative_14.txt': 3, 'narrative_10.txt': 3, 'narrative_2.txt': 3, '3.txt': 3, '2.txt': 3, 'narrative_11.txt': 3, 'narrative_13.txt': 3, 'narrative_1.txt': 3, 'narrative_0.txt': 3, 'narrative_12.txt': 3, '26.txt': 3, '32.txt': 3, '33.txt': 3, '27.txt': 3, '31.txt': 3, '19.txt': 3, '18.txt': 3, '24.txt': 3, '30.txt': 3, 'narrative_23.txt': 2, 'narrative_22.txt': 2, 'narrative_21.txt': 2, 'narrative_25.txt': 2, 'narrative_24.txt': 2, 'narrative_26.txt': 2, '9.txt': 2, '8.txt': 2, '7.txt': 2, 'narrative_3.txt': 2, 'min_5.txt': 2, 'min_4.txt': 2, 'min_6.txt': 2, 'min_19.txt': 2, 'min_3.txt': 2, 'min_2.txt': 2, 'min_18.txt': 2, 'min_0.txt': 2, 'max_18.txt': 2, 'max_9.txt': 2, 'max_8.txt': 2, 'max_19.txt': 2, 'min_1.txt': 2, 'min_16.txt': 2, 'max_14.txt': 2, 'max_5.txt': 2, 'max_4.txt': 2, 'max_15.txt': 2, 'min_17.txt': 2, 'min_15.txt': 2, 'max_17.txt': 2, 'max_6.txt': 2, 'max_7.txt': 2, 'max_16.txt': 2, 'min_14.txt': 2, 'min_10.txt': 2, 'max_12.txt': 2, 'max_3.txt': 2, 'max_2.txt': 2, 'max_13.txt': 2, 'min_11.txt': 2, 'min_13.txt': 2, 'max_11.txt': 2, 'max_0.txt': 2, 'max_1.txt': 2, 'max_10.txt': 2, 'min_8.txt': 2, 'min_12.txt': 2, 'narrative_37.txt': 1, 'narrative_36.txt': 1, 'narrative_34.txt': 1, 'narrative_35.txt': 1, 'narrative_31.txt': 1, 'narrative_30.txt': 1, 'narrative_32.txt': 1, 'narrative_27.txt': 1, 'narrative_33.txt': 1, 'narrative_29.txt': 1, 'narrative_28.txt': 1, 'narrative_72.txt': 1, 'narrative_8.txt': 1, 'narrative_9.txt': 1, 'narrative_4.txt': 1, 'narrative_5.txt': 1, 'narrative_7.txt': 1, 'narrative_6.txt': 1, 'min_7.txt': 1, 'min_9.txt': 1})

# %%
for c, num in count_frequency.items():
    print(f"{c}: {num/(31+48+20)} of {31+48+20}")
# Out:
# 3: 0.31313131313131315 of 99
# 2: 0.48484848484848486 of 99
# 1: 0.20202020202020202 of 99
# 0: 0.0 of 99

# %%
names = ["aaron", "ida2024", "samuel"]

aaronlist = Path("outputs/pilot_2/annotation").rglob('aaron.zip')
samuellist = Path("outputs/pilot_2/annotation").rglob('samuel.zip')
idalist = Path("outputs/pilot_2/annotation").rglob('ida2024.zip')

aaron_annotated_docs = [str(path).split("/")[-2] for path in aaronlist]
samuel_annotated_docs = [str(path).split("/")[-2] for path in samuellist]
ida_annotated_docs = [str(path).split("/")[-2] for path in idalist]

overlap_annotated_docs = [doc for doc in aaron_annotated_docs if doc in samuel_annotated_docs and doc in ida_annotated_docs]
all_annotated_docs = list(set(aaron_annotated_docs + samuel_annotated_docs + ida_annotated_docs))

all_docs = aaron_annotated_docs + samuel_annotated_docs + ida_annotated_docs

overlap_pilot_1_docs = [doc for doc in overlap_annotated_docs if doc.startswith("narrative")]
overlap_pilot_2_docs = [doc for doc in overlap_annotated_docs if not doc.startswith("narrative")]
all_pilot_1_docs = [doc for doc in all_annotated_docs if doc.startswith("narrative")]
all_pilot_2_docs = [doc for doc in all_annotated_docs if not doc.startswith("narrative")]


print(f"In the first pilot study, we have {len(overlap_pilot_1_docs)} documents annotated by all annotators, {len(all_pilot_1_docs)} documents annotated by at least one annotator.")
print(f"In the second pilot study, we have {len(overlap_pilot_2_docs)} documents annotated by all annotators, {len(all_pilot_2_docs)} documents annotated by at least one annotator.")

names = ["ida2024", "samuel"]

samuellist = Path("outputs/pilot_3/annotation").rglob('samuel.zip')
idalist = Path("outputs/pilot_3/annotation").rglob('ida2024.zip')

samuel_annotated_docs = [str(path).split("/")[-2] for path in samuellist]
ida_annotated_docs = [str(path).split("/")[-2] for path in idalist]
overlap_pilot_3_docs = [doc for doc in samuel_annotated_docs if doc in ida_annotated_docs]
overlap_pilot_3_docs_min = [doc for doc in overlap_pilot_3_docs if "min" in doc]
overlap_pilot_3_docs_max = [doc for doc in overlap_pilot_3_docs if "max" in doc]
all_docs += samuel_annotated_docs + ida_annotated_docs
print(f"In the third pilot study, we have {len(overlap_pilot_3_docs)} documents annotated by all annotators. Min: {len(overlap_pilot_3_docs_min)}, Max: {len(overlap_pilot_3_docs_max)}")
# Out:
# In the first pilot study, we have 14 documents annotated by all annotators, 39 documents annotated by at least one annotator.
# In the second pilot study, we have 17 documents annotated by all annotators, 20 documents annotated by at least one annotator.
# In the third pilot study, we have 38 documents annotated by all annotators. Min: 18, Max: 20

# %%
annotation_dict = {"doc_id": [], "text": [], "annotator": [], "pilot": [], "doc_label": [], "triples": [], "spans": [], "relations": []}

docs_path = {
             "pilot_2" : [overlap_pilot_1_docs, overlap_pilot_2_docs],
             "pilot_3" : [overlap_pilot_3_docs_min+overlap_pilot_3_docs_max]
             }
df_pilot_all = []
helper = True
names = ["aaron", "ida2024", "samuel"]

    
annotation_dict = {"doc_id": [], "text": [], "annotator": [], "pilot": [], "doc_label": [], "triples": [], "spans": [], "relations": []}
for pilot, documents in docs_path.items():
    if "pilot_3" in pilot:
        names = ["ida2024", "samuel"]
    else:
        names = ["aaron", "ida2024", "samuel"]
    for j, docs in enumerate(documents):
        print(f"Processing {len(docs)} documents for {pilot}...")
        if j > 0:
            helper = False
        for i, doc in enumerate(docs):
            doc_id = doc.split(".")[0]
            with open(f'./outputs/{pilot}/annotation/{doc}/TypeSystem.xml', 'rb') as f:
                typesystem = load_typesystem(f)

            for name in names:
                #print(f"Processing {name} in document {doc} ({i+1}/{len(docs)})...")
                doc_labels = []
                spans = []
                relations = []

                try:
                    with open(f'./outputs/{pilot}/annotation/{doc}/{name}.xmi', 'rb') as f:
                        cas = load_cas_from_xmi(f, typesystem=typesystem)
                except FileNotFoundError:
                    print(f"File not found for {name} in document {doc}. Skipping.")
                    continue
                
                annotation_dict["annotator"].append(name)
                for doc_label in cas.select('custom.DocumentLabel'):
                    annotation_dict["doc_label"].append(doc_label.label)
                annotation_dict["spans"].append(cas.select('custom.Span'))
                annotation_dict["relations"].append(cas.select('custom.Relation'))
                triples = []
                for relation in cas.select('custom.Relation'):
                    if None in [relation.Governor.Events, relation.Dependent.DirectionofChange, relation.Dependent.Events]:
                        continue
                    else:
                        triples.append((relation.Governor.Events, relation.Dependent.DirectionofChange, relation.Dependent.Events))
                triples = set(triples)
                annotation_dict["doc_id"].append(doc_id)
                annotation_dict["triples"].append(triples)
                annotation_dict["text"].append(cas.sofa_string)
                if helper:
                    annotation_dict["pilot"].append("pilot_1")
                else:
                    annotation_dict["pilot"].append(pilot)
                    
        df = pd.DataFrame.from_dict(annotation_dict)
        df = df.replace({None: np.nan})
        df_pilot_all.append(df)
        reliability_data = [df[df["annotator"]==name].sort_values(by=['doc_id', 'text'], ascending=True)["doc_label"].values.tolist() for name in  names]
        print(reliability_data)
        print("K-alpha:", krippendorff.alpha(reliability_data=reliability_data, level_of_measurement="nominal"))
df_pilot_all = pd.concat(df_pilot_all, ignore_index=True)
df_pilot_all.to_csv("../data/annotated/pilot_annotation.csv", index=False)
# Out:
# Processing 14 documents for pilot_2...
# [['inflation-related', 'inflation-related', 'inflation-related', 'non-inflation-related', 'non-inflation-related', 'inflation-cause-related', 'non-inflation-related', 'inflation-cause-related', 'non-inflation-related', 'non-inflation-related', 'inflation-related', 'inflation-related', 'non-inflation-related', 'non-inflation-related'], ['inflation-related', 'inflation-related', 'inflation-cause-related', 'inflation-cause-related', 'non-inflation-related', 'inflation-cause-related', 'inflation-cause-related', 'inflation-cause-related', 'non-inflation-related', 'inflation-cause-related', 'inflation-related', 'inflation-related', 'non-inflation-related', 'non-inflation-related'], ['inflation-related', 'inflation-cause-related', 'inflation-cause-related', 'inflation-related', 'non-inflation-related', 'inflation-cause-related', 'inflation-cause-related', 'inflation-cause-related', 'non-inflation-related', 'non-inflation-related', 'inflation-cause-related', 'inflation-related', 'inflation-cause-related', 'non-inflation-related']]
# num of pairable: 42
# K-alpha: 0.47435897435897445
# Processing 17 documents for pilot_2...
# [['non-inflation-related', 'inflation-related', nan, 'inflation-related', 'inflation-related', 'non-inflation-related', 'inflation-related', 'inflation-related', 'non-inflation-related', 'non-inflation-related', 'non-inflation-related', 'inflation-cause-related', 'inflation-related', 'inflation-cause-related', 'inflation-related', nan, nan, 'inflation-related', 'inflation-related', 'inflation-related', 'non-inflation-related', 'non-inflation-related', 'inflation-cause-related', 'non-inflation-related', 'inflation-cause-related', 'non-inflation-related', 'non-inflation-related', 'inflation-related', 'inflation-related', 'non-inflation-related', 'non-inflation-related'], ['non-inflation-related', 'non-inflation-related', 'inflation-related', 'inflation-related', 'inflation-related', 'inflation-related', 'inflation-related', 'non-inflation-related', 'non-inflation-related', 'non-inflation-related', 'non-inflation-related', 'inflation-cause-related', 'inflation-related', nan, 'inflation-related', 'inflation-related', 'non-inflation-related', 'inflation-related', 'inflation-related', 'inflation-cause-related', 'inflation-cause-related', 'non-inflation-related', 'inflation-cause-related', 'inflation-cause-related', 'inflation-cause-related', 'non-inflation-related', 'inflation-cause-related', 'inflation-related', 'inflation-related', 'non-inflation-related', 'non-inflation-related'], ['non-inflation-related', 'non-inflation-related', 'inflation-related', 'non-inflation-related', 'inflation-related', 'non-inflation-related', 'inflation-related', 'inflation-related', 'non-inflation-related', 'inflation-related', 'non-inflation-related', 'inflation-cause-related', 'inflation-related', 'inflation-cause-related', 'inflation-related', 'inflation-related', 'non-inflation-related', 'inflation-related', 'inflation-cause-related', 'inflation-cause-related', 'inflation-related', 'non-inflation-related', 'inflation-cause-related', 'inflation-cause-related', 'inflation-cause-related', 'non-inflation-related', 'non-inflation-related', 'inflation-cause-related', 'inflation-related', 'inflation-cause-related', 'non-inflation-related']]
# num of pairable: 89
# K-alpha: 0.5719844357976653
# Processing 38 documents for pilot_3...
# [['non-inflation-related', 'non-inflation-related', 'inflation-related', 'inflation-related', 'inflation-related', 'inflation-related', 'inflation-related', 'non-inflation-related', 'non-inflation-related', 'non-inflation-related', 'non-inflation-related', 'inflation-cause-related', 'inflation-related', nan, 'inflation-related', 'inflation-related', 'non-inflation-related', 'inflation-related', 'inflation-related', 'inflation-cause-dominant', 'non-inflation-related', 'inflation-cause-dominant', 'inflation-related', 'inflation-related', 'inflation-related', 'non-inflation-related', 'inflation-cause-dominant', 'inflation-related', 'non-inflation-related', 'inflation-related', 'inflation-cause-dominant', 'non-inflation-related', 'non-inflation-related', 'inflation-related', nan, 'inflation-related', nan, 'inflation-related', 'inflation-related', 'inflation-cause-dominant', 'non-inflation-related', 'inflation-cause-dominant', 'inflation-related', 'inflation-related', 'inflation-related', 'non-inflation-related', 'inflation-cause-dominant', 'inflation-related', 'non-inflation-related', 'inflation-related', 'inflation-cause-dominant', 'non-inflation-related', 'non-inflation-related', 'inflation-related', 'inflation-related', 'inflation-related', 'inflation-related', 'inflation-cause-related', 'inflation-cause-related', 'non-inflation-related', 'inflation-cause-related', 'inflation-cause-related', 'inflation-cause-related', 'non-inflation-related', 'inflation-cause-related', 'inflation-related', 'inflation-related', 'non-inflation-related', 'non-inflation-related'], ['non-inflation-related', 'non-inflation-related', 'inflation-related', 'non-inflation-related', 'inflation-related', 'non-inflation-related', 'inflation-related', 'inflation-related', 'non-inflation-related', 'inflation-related', 'non-inflation-related', 'inflation-cause-related', 'inflation-related', 'inflation-cause-related', 'inflation-related', 'inflation-related', 'non-inflation-related', 'inflation-cause-dominant', 'inflation-cause-dominant', 'inflation-cause-dominant', 'non-inflation-related', 'inflation-cause-dominant', 'inflation-cause-dominant', 'inflation-related', 'inflation-related', 'non-inflation-related', 'inflation-cause-dominant', 'inflation-related', 'non-inflation-related', 'inflation-related', 'inflation-cause-dominant', 'inflation-cause-dominant', 'non-inflation-related', 'inflation-related', 'inflation-cause-dominant', 'inflation-cause-dominant', 'inflation-related', 'inflation-cause-dominant', 'inflation-cause-dominant', 'inflation-cause-dominant', 'non-inflation-related', 'inflation-cause-dominant', 'inflation-cause-dominant', 'inflation-related', 'inflation-related', 'non-inflation-related', nan, 'inflation-related', 'non-inflation-related', 'inflation-related', 'inflation-cause-dominant', 'inflation-cause-dominant', 'non-inflation-related', 'inflation-related', 'inflation-cause-dominant', 'inflation-related', 'inflation-cause-related', 'inflation-cause-related', 'inflation-related', 'non-inflation-related', 'inflation-cause-related', 'inflation-cause-related', 'inflation-cause-related', 'non-inflation-related', 'non-inflation-related', 'inflation-cause-related', 'inflation-related', 'inflation-cause-related', 'non-inflation-related']]
# num of pairable: 138
# K-alpha: 0.5879979828542612

# %%
df_pilot_all[df_pilot_all["pilot"]=="pilot_1"].groupby("annotator")["doc_label"].value_counts(normalize=True)
# Out:
# annotator  doc_label
# aaron      non-inflation-related      0.500000
#            inflation-related          0.357143
#            inflation-cause-related    0.142857
# ida2024    inflation-cause-related    0.428571
#            inflation-related          0.285714
#            non-inflation-related      0.285714
# samuel     inflation-cause-related    0.500000
#            non-inflation-related      0.285714
#            inflation-related          0.214286
# Name: proportion, dtype: float64

# %% [markdown]
# Proportion of inflation cause dominant
# 1. pilot 1: 0.357
# 2. pilot 2: 0.106
# 3. pilot 3: 0.356

# %%
reliability_data = [df[df["pilot"].isin(["pilot_3"])][df["annotator"]==name].sort_values(by='doc_id', ascending=True)["doc_label"].values.tolist() for name in  names]
print(reliability_data)
print("K-alpha:", krippendorff.alpha(reliability_data=reliability_data, level_of_measurement="nominal"))
# Out:
# [['inflation-related', 'inflation-related', 'inflation-cause-dominant', 'non-inflation-related', 'inflation-cause-dominant', 'inflation-related', 'inflation-related', 'inflation-related', 'non-inflation-related', 'inflation-cause-dominant', 'inflation-related', 'non-inflation-related', 'inflation-related', 'inflation-cause-dominant', 'non-inflation-related', 'non-inflation-related', 'inflation-related', nan, 'inflation-related', nan, 'inflation-related', 'inflation-related', 'inflation-cause-dominant', 'non-inflation-related', 'inflation-cause-dominant', 'inflation-related', 'inflation-related', 'inflation-related', 'non-inflation-related', 'inflation-cause-dominant', 'inflation-related', 'non-inflation-related', 'inflation-related', 'inflation-cause-dominant', 'non-inflation-related', 'non-inflation-related', 'inflation-related', 'inflation-related'], ['inflation-cause-dominant', 'inflation-cause-dominant', 'inflation-cause-dominant', 'non-inflation-related', 'inflation-cause-dominant', 'inflation-cause-dominant', 'inflation-related', 'inflation-related', 'non-inflation-related', 'inflation-cause-dominant', 'inflation-related', 'non-inflation-related', 'inflation-related', 'inflation-cause-dominant', 'inflation-cause-dominant', 'non-inflation-related', 'inflation-related', 'inflation-cause-dominant', 'inflation-cause-dominant', 'inflation-related', 'inflation-cause-dominant', 'inflation-cause-dominant', 'inflation-cause-dominant', 'non-inflation-related', 'inflation-cause-dominant', 'inflation-cause-dominant', 'inflation-related', 'inflation-related', 'non-inflation-related', nan, 'inflation-related', 'non-inflation-related', 'inflation-related', 'inflation-cause-dominant', 'inflation-cause-dominant', 'non-inflation-related', 'inflation-related', 'inflation-cause-dominant']]
# num of pairable: 76
# K-alpha: 0.5708955223880596
# /var/folders/cm/3bzwnl_s7n90ryczc4tgbl_r0000gn/T/ipykernel_26542/3292943847.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   reliability_data = [df[df["pilot"].isin(["pilot_3"])][df["annotator"]==name].sort_values(by='doc_id', ascending=True)["doc_label"].values.tolist() for name in  names]
# /var/folders/cm/3bzwnl_s7n90ryczc4tgbl_r0000gn/T/ipykernel_26542/3292943847.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   reliability_data = [df[df["pilot"].isin(["pilot_3"])][df["annotator"]==name].sort_values(by='doc_id', ascending=True)["doc_label"].values.tolist() for name in  names]

# %%
df = df_pilot_all.sort_values(by=['text','pilot'], ascending=True)
df
# Out:
#     doc_id                                               text annotator  \
# 260  min_8  &apos;Moderate&apos; Recession In Offing For C...   ida2024
# 261  min_8  &apos;Moderate&apos; Recession In Offing For C...    samuel
# 268  max_8  &apos;Moderate&apos; Recession In Offing For C...   ida2024
# 269  max_8  &apos;Moderate&apos; Recession In Offing For C...    samuel
# 84      29  3M to Cut Costs as Business Cools Beyond Masks...     aaron
# ..     ...                                                ...       ...
# 106      2  Will Stocks Be a Trade-War Casualty? -- Barron...   ida2024
# 107      2  Will Stocks Be a Trade-War Casualty? -- Barron...    samuel
# 198      2  Will Stocks Be a Trade-War Casualty? -- Barron...     aaron
# 199      2  Will Stocks Be a Trade-War Casualty? -- Barron...   ida2024
# 200      2  Will Stocks Be a Trade-War Casualty? -- Barron...    samuel
#
#        pilot                 doc_label  \
# 260  pilot_3         inflation-related
# 261  pilot_3  inflation-cause-dominant
# 268  pilot_3         inflation-related
# 269  pilot_3  inflation-cause-dominant
# 84   pilot_2     non-inflation-related
# ..       ...                       ...
# 106  pilot_2         inflation-related
# 107  pilot_2     non-inflation-related
# 198  pilot_2     non-inflation-related
# 199  pilot_2         inflation-related
# 200  pilot_2     non-inflation-related
#
#                                       triples  \
# 260                                        {}
# 261  {(Monetary Policy, Increase, Inflation)}
# 268                                        {}
# 269  {(Monetary Policy, Decrease, Inflation)}
# 84                                         {}
# ..                                        ...
# 106                                        {}
# 107                                        {}
# 198                                        {}
# 199                                        {}
# 200                                        {}
#
#                                                  spans  \
# 260                                                 []
# 261  [c.Span(Events=Monetary Policy, Is_Nuclei=Cons...
# 268                                                 []
# 269  [c.Span(Events=Monetary Policy, Is_Nuclei=Cons...
# 84                                                  []
# ..                                                 ...
# 106                                                 []
# 107                                                 []
# 198                                                 []
# 199                                                 []
# 200                                                 []
#
#                                              relations
# 260                                                 []
# 261  [c.Relation(Dependent=c.Span(DirectionofChange...
# 268                                                 []
# 269  [c.Relation(Dependent=c.Span(DirectionofChange...
# 84                                                  []
# ..                                                 ...
# 106                                                 []
# 107                                                 []
# 198                                                 []
# 199                                                 []
# 200                                                 []
#
# [304 rows x 8 columns]

# %%
df_pilot_all[df_pilot_all["annotator"]=="ida2024"].text.value_counts()
# Out:
# text
# USDA National Pork Midday FOB Plant Report - Oct 10 \n\n\n\nLM_PK600 \n \nDes Moines, IA              Wed, Oct 10, 2018                  USDA Market News \nNATIONAL DAILY PORK REPORT FOB PLANT - Negotiated Sales - Morning \n \n-------------------------------------------------------------------------------- \nLoads PORK CUTS          :     173.61 \nLoads TRIM/PROCESS PORK  :     27.32 \n-------------------------------------------------------------------------------- \nUSDA ESTIMATED PORK CUT-OUT VALUES - as of 9:30am \nBased on negotiated prices and volume of pork cuts delivered within 14 days \nand on average industry cutting yields.  Values reflect U.S. dollars per \n100 pounds. \nCalculations for 205 lb Pork Carcass. 53-54% lean, 0.65"-0.80" BF Last Rib \n-------------------------------------------------------------------------------- \n                      Today's Estimated Primal Cutout \n \nDate            Loads  Carcass    Loin    Butt     Pic     Rib     Ham   Belly \n-------------------------------------------------------------------------------- \n10/10/2018     200.93    79.51   77.45   98.24   52.92  122.46   56.49  134.21 \nChange:                   0.45   -2.54    2.76    0.53    1.35    1.26    1.78 \n-------------------------------------------------------------------------------- \n10/09/2018    428.01     79.06   79.99   95.48   52.39  121.11   55.23  132.43 \n10/08/2018    302.93     78.93   79.58   96.46   52.47  117.77   55.76  130.39 \n10/05/2018    261.37     79.56   80.49   99.72   52.11  116.02   59.16  126.91 \n10/04/2018    307.39     79.91   80.15   99.80   50.16  119.57   61.78  125.69 \n \n \nFive Day Average --      79.39   79.53   97.94   52.01  119.39   57.68  129.93 \n-------------------------------------------------------------------------------- \n                                           Pounds      Price Range     Wtd Avg \nLoin \n \n 1/4 Trimmed Loin VAC                      257,780   91.00  - 117.00   96.52 \n 1/4 Trimmed Loin VAC, FZN                 5,401     93.00  - 96.00    93.63 \n 1/4 Trimmed Loin Paper                                     - \n 1/4 Trimmed Loin Paper, FZN                                - \n 1/4 Trimmed Loin Combo                    157,781   80.00  - 80.50    80.07 \n 1/8 Trimmed Loin VAC                      79,144    89.63  - 123.15   101.89 \n 1/8 Trimmed Loin VAC, FZN                                  - \n 1/8 Trimmed Loin Paper                    17,331    101.50 - 122.50   114.27 \n 1/8 Trimmed Loin Paper, FZN                                - \n 1/8 Trimmed Loin Combo                    191,442   87.00  - 97.50    87.22 \n Bone-in CC, Tender-in Loin VAC            113,289   126.00 - 165.15   145.75 \n Bone-in CC, Tender-in Loin VAC, FZN                        - \n Bone-in CC, Tender-in Loin Combo                           - \n B-In CC, Tender-in, FLON Loin             59,862    120.15 - 156.63   135.56 \n B-In CC, Tender-in, FLON Loin, FZN                         - \n Bnls CC Strap-on                          184,150   133.00 - 172.00   154.44 \n Bnls CC Strap-on, FZN                                      - \n Bnls CC Strap-off                         338,034   121.94 - 177.00   138.37 \n Bnls CC Strap-off, FZN                    3,559     175.41 - 186.50   180.26 \n Bnls CC Strap-on, 1/2 cut                 12,740    145.50 - 156.00   146.24 \n Bnls CC Strap-on, 1/2 cut, FZN                             - \n Bnls CC Strap-off, 1/2 cut                8,372     154.00 - 184.00   166.87 \n Bnls CC Strap-off, 1/2 cut, FZN                            - \n Whole Bnls Strap-on                                        - \n Boneless Sirloin                          239,684   85.82  - 123.00   95.15 \n Boneless Sirloin, FZN                                      - \n Boneless Sirloin, Combo                                    - \n Bone-in Sirloin                           70,354    62.50  - 92.00    67.16 \n Bone-in Sirloin, FZN                                       - \n Blade ...
# Administration Sued On Drilling Permits -- WSJ \n\n\n\nBy Katy Stech Ferek \n\n     Environmental groups sued the Biden administration on Wednesday, saying that its decision to approve more than 3,500 oil and natural-gas drilling permits in New Mexico and Wyoming violated environmental laws by not taking into account the impact on climate change. \n\n     In their lawsuit filed in U.S. District Court in Washington, D.C., the conservation nonprofits Center for Biological Diversity and WildEarth Guardians say the approved oil and gas wells will release as much as 600 million metric tons of greenhouse-gas emissions, worsening climate change and damaging U.S. ecosystems. \n\n     The federal permitting agency "has admitted that continued oil and gas exploitation is a significant cause of the climate crisis, yet the agency continues to recklessly issue thousands of new oil and gas drilling permits," said Kyle Tisdel, climate and energy program director with the Western Environmental Law Center, which filed the lawsuit on behalf of the nonprofits. \n\n     "While President Biden has acknowledged the urgency of this crisis, it is time for action to align with rhetoric," he said. \n\n     Specifically, the groups said that the Interior Department's Bureau of Land Management, which handles oil and gas drilling on federal lands, violated the National Environmental Policy Act by failing to account for how approving the permits would affect the climate and nearby communities. They also said Bureau of Land Management officials failed to prevent "unnecessary and undue degradation of public lands," a requirement of the Federal Land Policy and Management Act. \n\n     Interior Department spokeswoman Melissa Schwartz declined to comment on the lawsuit. \n\n     The lawsuit is unlikely to have an immediate effect on U.S. energy prices. While the groups asked a judge to declare the permits to be unlawfully granted and to invalidate them, they didn't ask the court to immediately stop drilling-related activity under the permits. \n\n     Roughly 10% of U.S. oil and gas production comes from federal land. Most comes from state and private land. Additionally, federal actions taken on oil and gas drilling development are likely to take months, if not years, to affect U.S. production that could add to supply. \n\n     Since prices began to rise, the Biden administration encouraged drilling companies to increase production and said they could do so using some of the 9,000 approved-but-unused permits. \n\n     The encouragement has frustrated climate groups that said Mr. Biden is violating a campaign-trail promise to end oil and gas drilling on federal lands. Mr. Biden ordered a moratorium on new leases on the day he took office pending a federal report on the leasing program, which came out in November. Before the report, the moratorium was put on hold by a federal-district court judge in Louisiana. In April, Interior officials announced new lease sales
surprisingly robust demand. \n\n \nChina's Big Banks Report Profit Drops \n \n\n  China's major banks reported their biggest profit drops in more than a decade, as the economic impact of the pandemic led them to take large provisions against potential bad loans. \n\n \nIndividual-Investor Boom Reshapes Stock Market \n \n\n  It's one of the year's biggest market stories: Mom-and-pop investors have fallen back in love with stocks, lured by free trading apps, a resurgent bull market led by technology companies and a pandemic that has left millions of Americans at home with little to do. \n\n \nChina's Attempts to Spur Consumption Show Signs of Working \n \n\n  A gauge of Chinese business activity outside the factory floor rose to its highest level in 2 1/2 years in August, driven by the service sector. \n\n \nItaly's 2Q GDP Fell More Than Initially Estimated \n \n\n  The Italian economy's nosedive during the second quarter was slightly more severe than previously estimated, data from the country's statistics office, Istat, showed. \n\n \n \n\n  (END) Dow Jones Newswires\n\n  August 31, 2020 15:00 ET (19:00 GMT)\n                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    ...
# Inflation&apos;s Mild Reappearance -- Barrons.com \n\n\n\nEdited by Paul Farrell \n\n     Inflation Returns, Mildly \n\n     Economic Update by Regions Financial April 11: After having been oddly muted, inflation found its voice in March. But rather than a roar, it came back with more of a polite whisper. The total consumer price index fell by 0.1% in March, matching our forecast (the consensus was for no change), with core CPI rising by 0.2%, matching the consensus and ahead of our forecast of a 0.1% increase. It is the over-the-year comparisons, however, that were the focus ahead of today's release. It is the base effects [from the corresponding period of the prior year] -- including the precipitous decline in prices for cellphone service, beginning last March -- that made the over-the-year increases in both the headline and the core CPI look much worse in the March data. While energy prices muted the over-the-year change in the headline CPI, up 2.4%, those base effects were more pronounced in the core CPI, which stands 2.1% higher year-on-year compared with 1.8% higher in February. These over-the-year increases were smaller than many had feared. To which we'll say, just wait a month, as those changes will become more pronounced, beginning with the April data. So, even if inflation itself isn't screaming at us a month from now, the headlines atop the stories about inflation surely will be. \n\n     Retail gasoline prices were flat on a monthly average basis in March, contrary to the sizable increase for which the seasonal adjustment factors were geared. As a result, the seasonally adjusted gas prices were down 4.9%, month on month, which cut 0.2 of a percentage point off the change in the headline CPI. (This cut will disappear in the April data.) \n\n     The reaction in the financial markets to the March inflation data has leaned more toward indifference than fear, and we suspect the reaction within the Federal Open Market Committee will be much the same. The base effects in the inflation data are no surprise, or at least shouldn't be, and discounting the noise from gasoline prices, virtually everyone, the FOMC included, expects inflation to pick up. To the extent that the pickup remains orderly, it won't alter the FOMC's view of the appropriate path of monetary policy. -- Richard F. Moody \n\n     Consumers Flinch, But Are Basically Optimistic \n\n     Commentary and Analysis by Maria Fiorini Ramirez Inc. April 12: The University of Michigan consumer sentiment index for April was preliminarily reported to have declined to 97.8 from a final March reading of 101.4. The April result compared to a median forecast of 100.4, and, while lower than the March outcome (which was the best since 2004), is nonetheless very strong in absolute terms. The decline in April was attributed by the University of Michigan mostly to concerns about a possible trade war, and these worries were heavily skewed by political party, just as the overall expectations of the index have been. \n\n     Earlier outcomes were 99.7 in February, 95.7 in January, 95.9 in December, 98.5 in November, 100.7 in October (previously the best reading since 2004), 95.1 in September, 96.8 in August, 93.4 in July, 95.1 in June, 97.1 in May, 97.0 in April, 96.9 in March, 96.3 in February, and 98.5 in January, 98.2 in December, 93.8 in November, and 87.2 in October of 2016. \n\n     This measure, along with the Conference Board's consumer confidence index, is at a robust level, indicating overall consumer attitudes remain very positive. --Joshua Shapiro \n\n     To be considered for this section, material, with the author's name and address, should be sent to MarketWatch@barrons.com. \n\n \n\n  (END) Dow Jones Newswires\n\n  April 13, 2018 15:33 ET (19:33 GMT)\n                                                                                                                                                                                                                         ...
# Commodities Corner: U.S. Shale Threatens OPEC -- Barron&apos;s \n\n\n\nBy Myra P. Saefong \n\n     Oil is among the biggest commodity gainers in 2019, with prices up by more than 20% -- a testament to the success of the output cuts agreed to by major crude producers at the start of the year. \n\n     However, the cuts may run head-on into the effects of increased U.S. shale production and more output from other sources. That could test the resolve of some members of the Organization of Petroleum Exporting Countries, as well as their nonmember allies, which include Russia. "High compliance with the OPEC production cuts is impressive and clearly a significant driver of the rally in crude oil futures," says Marshall Steeves, energy markets analyst at Informa Economics. But outside of Gulf producers like Saudi Arabia, compliance with output reductions "may not necessarily remain high over time," he says. \n\n     OPEC members agreed to trim 800,000 barrels a day from October's production levels for six months through June 2019, with Russia and allied producers cutting 400,000 barrels more a day, for 1.2 million barrels in total cuts. \n\n     Saudi Arabia's Energy Minister Khalid al-Falih recently told Reuters that it would be too early to change that pact before OPEC and its allies meet in June. The next official OPEC and non-OPEC meetings will be held on April 17 and 18. The Joint Ministerial Monitoring Committee, which monitors compliance with output cuts, will hold its next gathering on Monday, March 18. \n\n     The 11 OPEC members achieved 79% of their committed cuts in February, with OPEC's production at 30.8 million barrels a day, according to a S&P Global Platts survey. That's an improvement from the 76% compliance rate a month earlier. Year to date as of Friday, U.S. oil futures have rallied by 29%, while global prices climbed more than 25%, after dropping by 20% or more in 2018. \n\n     The commitment to cuts is surprising given OPEC concerns over loss of market share to producers such as the U.S. U.S. crude production hit a record above 12 million barrels a day in recent weeks, and the International Energy Agency expects the U.S. to lead the rise in global oil production over the next five years. The IEA projection "suggests the current trend of unconventional shale-production and offshore Gulf of Mexico production growth will likely continue at the expense of OPEC and allied producers," says Steeves. "If OPEC and its allies want to keep oil prices high, they will need to curtail supplies, meaning they will continue to lose market share to the U.S. and others." \n\n     Not everyone is convinced shale production will grow at a significant pace. "While I do see U.S. production growing, shale is expensive," says Matt Badiali, a senior research analyst at Banyan Hill Publishing. "Operators can exist at $50 to $55 per barrel, but they aren't making much money -- and they need credit to operate. So as interest rates rise, it will likely slow U.S. production growth." \n\n     For now, oil prices "have found a balance that could eventually prove precarious," with OPEC-led production cuts supporting higher prices, but increased output from the U.S. and elsewhere "keeping a lid on the market," Steeves says. \n\n     He expects U.S. benchmark West Texas Intermediate crude to trade in the mid-to-upper $50s in the next 30 to 60 days, with a wider range of $48 to $68 a barrel, while Brent trades in the upper $60s, within a wider range of $50 to $70. \n\n     "What could break the impasse amounts to either a quick rebalancing of global markets that could raise prices or signs of slower global economic growth that could lead to lower oil prices," says Steeves. \n\n     Myra P. Saefong writes about commodities for MarketWatch. \n\n     Email: editors@barrons.com \n\n \n\n  To subscribe to Barron's, visit http://www.barrons.com/subscribe \n\n  (END) Dow Jones Newswires\n\n  March 16, 2019 06:00 ET (10:00 GMT)\n                         ...
# Eurozone Inflation Jumped in November But Seen Slowing Down in 2022 -- Market Talk \n\n\n\n     1054 GMT - Eurozone inflation rose by 4.9% year-on-year in November, driven mainly by higher energy prices, even when all components saw marked accelerations, Oxford Economics says. There isn't much the European Central Bank can do about higher energy prices and supply bottlenecks in the short-term, but the latest data will add to the debate on the appropriate level of policy support, Oxford Economics' economist Katharina Koenz says. Oxford Economics still expects energy and goods price pressures to ease next year thanks to supply constraints fading. Therefore, the economic research group sticks to its view that inflation will slow meaningfully over the course of 2022. (maria.martinez@wsj.com) \n\n \n\n  (END) Dow Jones Newswires\n\n  November 30, 2021 05:54 ET (10:54 GMT)\n                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# ...
# Ecolab Sees 2Q Adjusted EPS Roughly Flat, 2022 Adjusted EPS Up \n\n\n\n \n\n  By Rob Curran \n\n \n\n  Ecolab Inc. forecast second-quarter operating earnings "approaching" year-earlier levels and growth in 2022 profit as it manages the effect of surging raw-material and energy costs by increasing prices and passing on an energy surcharge to customers. \n\n  The St. Paul, Minn., provider of water, hygiene and infection-prevention products and services forecast second-quarter adjusted earnings approaching the $1.22 a share level from the prior-year period. \n\n  For the full year, the company forecast adjusted earnings-per share growth in the low teens, based on the timing of the energy surcharge, which it is currently rolling out. The company said the temporary energy surcharge, intended to offset the increase in energy costs due to war in Ukraine, would be up to 12%, which it expects to "develop progressively through the year." The effects of the surcharge would become clearer as it exits the second quarter, the company said. \n\n  "While we expect the impact of substantial raw material and cost inflation to increase further in the second quarter and remain high for the balance of the year, we are also very pleased with our progress on pricing, and now expect it to be in the 6% to 7% range for the balance of the year," said President and Chief Executive Christophe Beck. \n\n \n\n  Write to Rob Curran at rob.curran@wsj.com \n\n \n\n  (END) Dow Jones Newswires\n\n  April 26, 2022 08:55 ET (12:55 GMT)\n                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            ...
# College Endowments Post Biggest Investment Losses Since Financial Crisis -- Barrons.com \n\n\n\nBy Mary Romano \n\n     University endowments posted their worst annual performance since the global financial crisis, battered by stock market losses, rising inflation, and higher interest rates. \n\n     Yet the biggest funds were helped by their higher allocations to alternative investments such as private equity, venture capital, and hedge funds. These investments, which offer a buffer against stock market losses but can be volatile, didn't lose as much ground even as their valuations declined with the market. Fund managers and industry experts warn, though, that further declines in these investments will contribute to any endowment losses in fiscal 2023. \n\n     Yale University's $41.4 billion fund, which had targeted just 2.3% for public equities and 47% to alternative investments such as venture capital and hedge funds, gained 0.8% in fiscal 2022. \n\n     "In such a volatile year for the world's financial markets, we are pleased to have protected Yale's capital," Yale Chief Investment Officer Matt Mendelsohn said in a statement. "That said, we expect challenging times ahead as rising interest rates, inflation and the geopolitical environment provide stiff headwinds." \n\n     School funds lost a median 7.8% in the 12 months through June 30, according to preliminary figures from investment firm Cambridge Associates. That is the worst showing since 2009, when the decline was a median 19%. The last time endowments saw investment losses was in 2016, when they slumped 1.95% on average, according to TIAA and the National Association of College and University Business Officers. \n\n     Despite the losses, endowments held up better in the same 2022 period than the S&P 500's loss of 10.6% with reinvested dividends. \n\n     "The losses are coming from public equities, no question," Margaret Chen, global head of the endowment and foundation practice at Cambridge Associates, says of the 2022 performance. "The higher the exposure, the more challenging the return for the fiscal year. The higher the private investments, the better your return on a relative basis." \n\n     Endowments with more than $1 billion had about 48% of their holdings in investments including private equity, venture capital, and hedge funds, and just 9.9% in U.S. equities as of fiscal 2021, the latest figures available, according to TIAA and NACUBO. Smaller funds -- $251 million to $500 million in assets -- had 26.1% in private investments and 25.2% in U.S. stocks. \n\n     The turnaround in performance follows a blockbuster fiscal 2021. Endowments gained 30.6%, on average, in the 12 months through June 30, 2021, according to TIAA and NACUBO. For instance, Duke University's endowment had an investment loss of 1.5% for fiscal 2022, compared with a 55.9% gain in the prior year. \n\n     "It was a dramatic swing in performance from the last fiscal year to this fiscal year, and it's challenging to manage through that," Chen says. \n\n     Harvard on Thursday said its $50.9 billion fund lost 1.8%. The fund's strongest performers were its investments in private equity and venture capital, said Narv Narvekar, CEO of Harvard Management Company, which manages the endowment. \n\n     "The more private assets an investor had in its portfolio in FY22, the stronger their performance," Narvekar wrote in Harvard's annual report. "This is somewhat counterintuitive and may indicate that private managers have not yet marked their portfolios to reflect general market conditions." \n\n     He added that "we expect that the end of the current calendar year might present meaningful adjustments to these valuations, as investment managers audit their portfolios." \n\n     Such markdowns are already happening, Chen says. \n\n     "We are seeing them being marked down as the market declines further," Chen says. "Fiscal 2023 will be more indicative of how things are marked down since there' ...
# U.S. Consumer Prices Rose 0.2% in July \n\n\n\nBy Josh Mitchell and Sarah Chaney \n\n     WASHINGTON -- Inflation picked up modestly in July, eating up Americans' wage gains. \n\n     The consumer-price index -- a broad measure of Americans' living expenses, from groceries to dental care -- rose 0.2% from a month earlier, the Labor Department said Friday. Excluding food and energy components, so-called core prices rose 0.2% as well. \n\n     The increases fell in line with economists' expectations. \n\n     Overall prices have climbed 2.9% over the past year, near the biggest gains of the expansion. Core prices increased 2.4%, the biggest 12-month gain since September 2008. \n\n     The report suggests inflation is steadily, but not rapidly, increasing as the economy heats up. The latest gain is likely to reassure the Federal Reserve as it considers raising interest rates -- it has penciled in two more increases for this year -- to keep the economy on an even keel. \n\n     But the higher prices also mean Americans' are losing purchasing power. A separate report released Friday showed average hourly earnings were flat in July, and average weekly earnings fell 0.2%. \n\n     Over the past year, average hourly earnings have fallen 0.2% while weekly earnings have climbed 0.1%. \n\n     The weak growth in earnings, relative to inflation, could constrain Americans' ability to spend and thus weigh on the broader economy. \n\n     Higher housing costs drove last month's gain in overall prices. A rise in so-called shelter costs -- reflecting rent and mortgage costs -- accounted for 60% of last month's gain in the overall index. \n\n     Broadly, most consumer prices are rising over the past year. Energy prices have climbed 12.1% over the past 12 months, driven by higher gasoline costs. \n\n     The inflation outlook is cloudy. Tariffs imposed by the Trump administration could push up inflation. But a rise in the dollar could weigh on it. \n\n     Write to Josh Mitchell at joshua.mitchell@wsj.com and Sarah Chaney at sarah.chaney@wsj.com \n\n \n\n  (END) Dow Jones Newswires\n\n  August 10, 2018 08:33 ET (12:33 GMT)\n                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 ...
# Name: count, dtype: int64
